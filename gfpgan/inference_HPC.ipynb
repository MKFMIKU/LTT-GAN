# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import glob

import cv2

import numpy as np

import torch
from torchvision.transforms.functional import normalize
from gfpgan.archs.gfpganv1_arch import GFPGANv1
from gfpgan.archs.gfpganpyramid_arch import GFPGANPyramid
from basicsr.utils import img2tensor, tensor2img

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

from PIL import Image

# %%
gfpgan = GFPGANPyramid(
    out_size=512,
    num_style_feat=512,
    channel_multiplier=1,
    decoder_load_path=None,
    fix_decoder=True,
    num_mlp=8,
    input_is_latent=True,
    different_w=True,
    narrow=1,
    sft_half=False,
    g=6)

# %%
gfpgan.eval()
# Out:
# GFPGANPyramid(
#   (conv_body_first): ConvLayer(
#     (0): EqualConv2d(in_channels=3, out_channels=16, kernel_size=1, stride=1, padding=0, bias=False)
#     (1): FusedLeakyReLU()
#   )
#   (conv_body_down): ModuleList(
#     (0): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=16, out_channels=32, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=16, out_channels=32, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (1): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=32, out_channels=64, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (2): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=64, out_channels=128, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=64, out_channels=128, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (3): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=128, out_channels=256, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=128, out_channels=256, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (4): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (5): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#     (6): ResBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=2, padding=0, bias=False)
#         (2): FusedLeakyReLU()
#       )
#       (skip): ConvLayer(
#         (0): UpFirDnSmooth(upsample_factor=1, downsample_factor=2)
#         (1): EqualConv2d(in_channels=256, out_channels=256, kernel_size=1, stride=2, padding=0, bias=False)
#       )
#     )
#   )
#   (final_conv): ConvLayer(
#     (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#     (1): FusedLeakyReLU()
#   )
#   (conv_body_up): ModuleList(
#     (0): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (1): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (2): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (3): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (4): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (5): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#     (6): ResUpBlock(
#       (conv1): ConvLayer(
#         (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=False)
#         (1): FusedLeakyReLU()
#       )
#       (conv2): ConvUpLayer(
#         (activation): FusedLeakyReLU()
#       )
#       (skip): ConvUpLayer()
#     )
#   )
#   (toRGB): ModuleList(
#     (0): EqualConv2d(in_channels=256, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (1): EqualConv2d(in_channels=256, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (2): EqualConv2d(in_channels=256, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (3): EqualConv2d(in_channels=128, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (4): EqualConv2d(in_channels=64, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (5): EqualConv2d(in_channels=32, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#     (6): EqualConv2d(in_channels=16, out_channels=3, kernel_size=1, stride=1, padding=0, bias=True)
#   )
#   (final_linear): EqualLinear(in_channels=4096, out_channels=8192, bias=True)
#   (stylegan_decoder): StyleGAN2GeneratorSFTPY(
#     (style_mlp): Sequential(
#       (0): NormStyleCode()
#       (1): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (2): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (3): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (4): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (5): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (6): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (7): EqualLinear(in_channels=512, out_channels=512, bias=True)
#       (8): EqualLinear(in_channels=512, out_channels=512, bias=True)
#     )
#     (constant_input): ConstantInput()
#     (style_conv1): StyleConv(
#       (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=None)
#       (activate): FusedLeakyReLU()
#     )
#     (to_rgb1): ToRGB(
#       (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#     )
#     (style_convs): ModuleList(
#       (0): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (1): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (2): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (3): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (4): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (5): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=512, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (6): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=256, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (7): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=256, out_channels=256, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (8): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=256, out_channels=128, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (9): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=128, out_channels=128, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (10): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=128, out_channels=64, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (11): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=64, out_channels=64, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#       (12): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=64, out_channels=32, kernel_size=3, demodulate=True, sample_mode=upsample)
#         (activate): FusedLeakyReLU()
#       )
#       (13): StyleConv(
#         (modulated_conv): ModulatedConv2d(in_channels=32, out_channels=32, kernel_size=3, demodulate=True, sample_mode=None)
#         (activate): FusedLeakyReLU()
#       )
#     )
#     (to_rgbs): ModuleList(
#       (0): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (1): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (2): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=512, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (3): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=256, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (4): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=128, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (5): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=64, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#       (6): ToRGB(
#         (upsample): UpFirDnUpsample(factor=2)
#         (modulated_conv): ModulatedConv2d(in_channels=32, out_channels=3, kernel_size=1, demodulate=False, sample_mode=None)
#       )
#     )
#     (noises): Module()
#   )
#   (condition_scale_a): ModuleList(
#     (0): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (1): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (2): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (3): Sequential(
#       (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (4): Sequential(
#       (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (5): Sequential(
#       (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (6): Sequential(
#       (0): EqualConv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#   )
#   (condition_scale_b): ModuleList(
#     (0): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (1): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (2): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (3): Sequential(
#       (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (4): Sequential(
#       (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (5): Sequential(
#       (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (6): Sequential(
#       (0): EqualConv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#   )
#   (condition_shift_a): ModuleList(
#     (0): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (1): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (2): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (3): Sequential(
#       (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (4): Sequential(
#       (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (5): Sequential(
#       (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (6): Sequential(
#       (0): EqualConv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#   )
#   (condition_shift_b): ModuleList(
#     (0): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (1): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (2): Sequential(
#       (0): EqualConv2d(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (3): Sequential(
#       (0): EqualConv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (4): Sequential(
#       (0): EqualConv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (5): Sequential(
#       (0): EqualConv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#     (6): Sequential(
#       (0): EqualConv2d(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1, bias=True)
#       (1): ScaledLeakyReLU()
#       (2): EqualConv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1, bias=True)
#     )
#   )
# )

# %%
# loadnet = torch.load('/home/viu/Work/GFPGAN/experiments/A100/train_GFPGANv1_512_simple_tub_cx_py_g8_4A100/models/net_g_155000.pth')
loadnet = torch.load('/hdd1/Turbulence/LTTGAN/experiments/ab_GFPGANv1_512_simple_blur2_cx_py_g16/models/net_g_80000.pth')
# loadnet = torch.load('/hdd1/Turbulence/LTTGAN/experiments/train_GFPGANv1_512_simple_tub/models/net_g_800000.pth')
if 'params_ema' in loadnet:
    keyname = 'params_ema'
else:
    keyname = 'params'
gfpgan.load_state_dict(loadnet[keyname], strict=True)
gfpgan.eval()
gfpgan = gfpgan.to('cuda:0')

# %%
# tub_faces = glob.glob('/data/datasets/Turbulence/Tubfaces95/300M/tubimages/*.png')
tub_faces = glob.glob('/data/datasets/Turbulence/CelebaAHQ100/tubimages/*.png')
# tub_faces = glob.glob('/data/datasets/BFR/lq/*.jpg')
tub_faces.sort()
len(tub_faces)
# Out:
# 100

# %%
idx = 95
# tub_face4img = cv2.imread('/hdd1/Datasets/Turbulence_data/Victorem_0140__None_PC00C00__R1/001.png', cv2.IMREAD_COLOR)
tub_face_img = cv2.imread(tub_faces[idx], cv2.IMREAD_COLOR)

tub_face_img_th = img2tensor(tub_face_img / 255., bgr2rgb=True, float32=True)
normalize(tub_face_img_th, (0.5, 0.5, 0.5), (0.5, 0.5, 0.5), inplace=True)
tub_face_img_th = tub_face_img_th.unsqueeze(0).to('cuda:0')

with torch.no_grad():
    outputs = gfpgan(tub_face_img_th, return_rgb=False)[0]
    output = torch.mean(outputs, dim=0)
    output = outputs[7]

plt.figure(figsize=(18, 12))
plt.subplot(1,2,1)
plt.imshow(tensor2img(output, rgb2bgr=False, min_max=(-1, 1)))

plt.subplot(1,2,2)
plt.imshow(tensor2img(tub_face_img_th, rgb2bgr=False, min_max=(-1, 1)))

# %%
noutputs = outputs[::2]
plt.figure(figsize=(16, 8), constrained_layout=True)
for i in range(noutputs.size(0)):
    plt.subplot(2,4,i+1)
    plt.imshow(tensor2img(noutputs[i], rgb2bgr=False, min_max=(-1, 1)))
    plt.axis('off')
plt.savefig('HPC.png', bbox_inches='tight', pad_inches=0)

# %%
for tub_face in tqdm(tub_faces):
    tub_face_img = cv2.imread(tub_face, cv2.IMREAD_COLOR)
    # face_helper.clean_all()
    # face_helper.read_image(tub_face_img)
    # face_helper.get_face_landmarks_5(only_center_face=True)
    # face_helper.align_warp_face()
    # if len(face_helper.cropped_faces) < 1:
    #     print(tub_face)
    #     break
    # tub_face_img = face_helper.cropped_faces[0]

    tub_face_img_th = img2tensor(tub_face_img / 255., bgr2rgb=True, float32=True)
    normalize(tub_face_img_th, (0.5, 0.5, 0.5), (0.5, 0.5, 0.5), inplace=True)
    tub_face_img_th = tub_face_img_th.unsqueeze(0).to('cuda:0')
    with torch.no_grad():
        outputs = gfpgan(tub_face_img_th, return_rgb=True)[0]
    output = torch.mean(outputs, dim=0)
    # output = gfpgan(tub_face_img_th, return_rgb=False)[0]
    restored_face_img = tensor2img(output.squeeze(0), rgb2bgr=True, min_max=(-1, 1))
 
    restored_face_img_compare = np.concatenate([tub_face_img, restored_face_img], axis=1)
    cv2.imwrite(os.path.join('/data/datasets/Turbulence/Tubfaces95/300M/comparisons/GFPGAN_tub', os.path.basename(tub_face)), restored_face_img)
    # cv2.imwrite(os.path.join('/data/datasets/real_tubface_99/frames/PC00C00_R1_frame_faces', os.path.basename(tub_face)), tub_face_img)
# Out:
#   0%|          | 0/267 [00:00<?, ?it/s]
